# %% [markdown]
# # I Solving the Sum of Two Digits Programming Challenge

# %% [markdown]
# ## C++

# %%
# %%writefile sum.cpp
# #include <iostream>
#
# int sum_of_two_digits(int first_digit, int second_digit) {
#     return first_digit + second_digit;
# }
#
# int main() {
#     int a = 0;
#     int b = 0;
#     std::cin >> a;
#     std::cin >> b;
#     std::cout << sum_of_two_digits(a, b);
#     return 0;
# }
# Out:
# Overwriting sum.cpp

# %%
# !g++ sum.cpp -o sum
# !./sum
# Out:
# 1 2
# 3

# %% [markdown]
# ### Test input output files

# %%
# %%writefile input1.txt
# 4 8
# Out:
# Writing input1.txt

# %%
# %%writefile output1.txt
# 12
# Out:
# Writing output1.txt

# %%
# %%writefile input2.txt
# -5 9
# Out:
# Writing input2.txt

# %%
# %%writefile output2.txt
# 4
# Out:
# Overwriting output2.txt

# %%
# !./sum < input1.txt
# Out:
# 12

# %%
# !./sum < input2.txt
# Out:
# 4

# %% [markdown]
# ### Comparing files with grep
#
# https://askubuntu.com/questions/546796/comparing-two-text-files

# %%
# !grep -xvFf output1.txt output1.txt

# %%
# !grep -xvFf output1.txt output2.txt
# Out:
# 4

# %%
# !grep -xvFf output2.txt output1.txt
# Out:
# 12

# %%
# !./sum < input1.txt> ctest1.txt
# !grep -xvFf output1.txt ctest1.txt

# %%
# !./sum < input2.txt > ctest2.txt
# !grep -xvFf output2.txt ctest2.txt

# %% [markdown]
# ## Python

# %%
# %%writefile sum.py
# python3


def sum_of_two_digits(first_digit, second_digit):
    return first_digit + second_digit

if __name__ == '__main__':
    a, b = map(int, input().split())
    print(sum_of_two_digits(a, b))
# Out:
# Writing sum.py

# %%
# !python sum.py
# Out:
# 4 7
# 11

# %%
# !python sum.py  < input1.txt> ptest1.txt
# !grep -xvFf output1.txt ptest1.txt

# %%
# !python sum.py  < input2.txt> ptest2.txt
# !grep -xvFf output2.txt ptest2.txt

# %% [markdown]
# # II Solving The Maximum Pairwise Product Programming Challenge in C++

# %% [markdown]
# ## C++

# %%
# %%writefile max_pairwise_product1.cpp
# #include <iostream>
# #include <vector>
# #include <algorithm>
#
# int MaxPairwiseProduct(const std::vector<int>& numbers) {
#     int max_product = 0;
#     int n = numbers.size();
#
#     for (int first = 0; first < n; ++first) {
#         for (int second = first + 1; second < n; ++second) {
#             max_product = std::max(max_product,
#                 numbers[first] * numbers[second]);
#         }
#     }
#
#     return max_product;
# }
#
# int main() {
#     int n;
#     std::cin >> n;
#     std::vector<int> numbers(n);
#     for (int i = 0; i < n; ++i) {
#         std::cin >> numbers[i];
#     }
#
#     std::cout << MaxPairwiseProduct(numbers) << "\n";
#     return 0;
# }
# Out:
# Writing max_pairwise_product1.cpp

# %%
# !g++ max_pairwise_product1.cpp -o max_pairwise_product1
# !./max_pairwise_product1
# Out:
# 3
# 1 3 4
# 12

# %% [markdown]
# ### Test 1: lagest input numbers 200000 200000 in the input

# %%
# %%writefile input1.txt
# 5
# 1 3 200000 9 200000 23
# Out:
# Overwriting input1.txt

# %%
# !./max_pairwise_product1 < input1.txt
# Out:
# 1345294336

# %%
# %%writefile max_pairwise_product2.cpp
# #include <iostream>
# #include <vector>
# #include <algorithm>
#
# long long MaxPairwiseProduct(const std::vector<int>& numbers) {
#     long long max_product = 0LL;
# 	  long long aux_product = 0LL;
#     int n = numbers.size();
#
#     for (int first = 0; first < n; ++first) {
#         for (int second = first + 1; second < n; ++second) {
# 			       aux_product =  (long long) numbers[first] * numbers[second];
#             if ( max_product < aux_product)  {
# 				        max_product = aux_product;
#              }
#         }
#     }
#
#     return max_product;
# }
#
# int main() {
#     int n;
#     std::cin >> n;
#     std::vector<int> numbers(n);
#     for (int i = 0; i < n; ++i) {
#         std::cin >> numbers[i];
#     }
#
#     std::cout << MaxPairwiseProduct(numbers) << "\n";
#     return 0;
# }
# Out:
# Overwriting max_pairwise_product2.cpp

# %%
# !g++ max_pairwise_product2.cpp -o max_pairwise_product2
# !./max_pairwise_product2 < input1.txt
# Out:
# 40000000000

# %% [markdown]
# ### Test 2  generate a tests file with the maximun n 200000 numbres and measure time

# %% [markdown]
# ### Efficient solution

# %%
# %%writefile max_pairwise_productEfficient.cpp
# #include <iostream>
# #include <vector>
#
# using std::vector;
# using std::cin;
# using std::cout;
#
# long long MaxPairwiseProductRap(const vector<int> & numbers)
# {
#     int n=numbers.size();
#
#     int max_ind1=-1;
#     for(int i=0;i<n;i++)
#     {
#         if((max_ind1==-1) || (numbers[i]>numbers[max_ind1]))
#             max_ind1=i;
#     }
#
#     int max_ind2=-1;
#     for(int j=0;j<n;j++)
#     {
#         if((j!=max_ind1) && ((max_ind2==-1) || (numbers[j]>numbers[max_ind2])))
#             max_ind2=j;
#     }
#
#     return ((long long)(numbers[max_ind1]))*numbers[max_ind2];
# }
#
# int main()
# {
#     int n;
#     cin>>n;
#     vector<int> numbers(n);
#     for(int i=0;i<n;i++)
#     {
#         cin>>numbers[i];
#     }
#
#     long long resultado=MaxPairwiseProductRap(vector<int>(numbers));
#     cout<<resultado<<"\n";
#     return 0;
# }
# Out:
# Writing max_pairwise_productEfficient.cpp

# %% [markdown]
# Stress tests

# %%
# %%writefile max_pairwise_product_fast_stress_test.cpp
# #include <cstdlib>
# #include <iostream>
# #include <vector>
#
# using std::vector;
# using std::cin;
# using std::cout;
#
# long long MaxPairwiseProduct(const std::vector<int>& numbers) {
#     long long max_product = 0LL;
#     long long aux_product = 0LL;
#     int n = numbers.size();
#
#     for (int first = 0; first < n; ++first)
#     {
#         for (int second = first + 1; second < n; ++second)
#         {
#             aux_product =  (long long) numbers[first] * numbers[second];
#
#             if ( max_product < aux_product)
#             {
# 				        max_product = aux_product;
#             }
#         }
#     }
#
#     return max_product;
# }
#
# long long MaxPairwiseProductRap(const vector<int> & numbers)
# {
#     int n=numbers.size();
#
#     int max_ind1=-1;
#     for(int i=0;i<n;i++)
#     {
#         if((max_ind1==-1) || (numbers[i]>numbers[max_ind1]))
#             max_ind1=i;
#     }
#
#     int max_ind2=-1;
#     for(int j=0;j<n;j++)
#     {
#         if((j!=max_ind1) && ((max_ind2==-1) || (numbers[j]>numbers[max_ind2])))
#             max_ind2=j;
#     }
#
#     return ((long long)(numbers[max_ind1]))*numbers[max_ind2];
# }
#
# int main()
# {
#     while(true)
#     {
#         int n= rand() %10 +2;
#         cout<<n<<"\n";
#         vector<int> a;
#         for(int i=0;i<n;i++)
#         {
#             a.push_back(rand() % 100000);
#         }
#         for(int i=0;i<n;i++)
#         {
#             cout<<a[i]<<' ';
#         }
#         cout<<"\n";
#         long long res1=MaxPairwiseProduct(a);
#         long long res2=MaxPairwiseProductRap(a);
#         if(res1!=res2)
#         {
#             cout<<"Incorrecto: "<<res1<<' '<<res2<<"\n";
#             break;
#         }
#         else
#         {
#             cout<<"OK\n";
#         }
#     }
#     return 0;
# }

# %% [markdown]
# Measure with test file of the maximun n 200000 numbres

# %% [markdown]
# ## Python

# %%
def max_pairwise_product2 (numbers):
    max_ind1=-1
    n=len(numbers)
    for x in range(n):
        if((max_ind1==-1)or(numbers[x]>numbers[max_ind1])):
            max_ind1=x
    max_ind2=-1
    for y in range(n):
        if((y!=max_ind1)and((max_ind2==-1)or(numbers[y]>numbers[max_ind2]))):
            max_ind2=y
    return numbers[max_ind1]*numbers[max_ind2]



if __name__ == '__main__':
    input_n = int(input())
    input_numbers = [int(x) for x in input().split()]
    print(max_pairwise_product2(input_numbers))

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/Jbejaranos/AlgorithmsUN2021I/master/AlgorithmicToolbox/Week1/productoMax.png)
# ![alt text](https://raw.githubusercontent.com/Jbejaranos/AlgorithmsUN2021I/master/AlgorithmicToolbox/Week1/uno_mas_dos.png)
